# %% [markdown]
# <a href="https://colab.research.google.com/github/Nallikirankumar/kiran_fmml_labs_modules/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # K-NN ( K- Nearest Neighbour )

# %% [markdown]
# **What is KNN ?**

# %% [markdown]
# K-NN is a non-parametric and lazy learning algorithm. Non-parametric means there is no assumption for underlying data distribution i.e. the model structure is determined from the dataset.

# %% [markdown]
# # **Lazy Learning**
#
# It is called Lazy algorithm because it does not need any training data points for model generation. All training data is used in the testing phase which makes training faster and testing phase slower and costiler.

# %% [markdown]
# K_Nearest Neighbour (K-NN) is a simple algorithm that stores all the available casesand classifies the new data or case based on a similarity measure.

# %% [markdown]
# # K-NN classification
# In K-NN classification, the output is a class membership. An object is classified by a plurality vote of its neighbours, with the object being assigned to the class most common among its k nearest neighbours (k is a positive integer, typically small). if k = 1, then the object is simply assigned to the class of that single nearest neighbour.

# %% [markdown]
# To determine which of the K instances in the training dataset are most similar to a new input, a distance measure is used. For real-valued input variables, the most popular distance measure is the Euclidean distance.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Euclidean distance is a basic type of distance that we define in geometry. The distance between two poins is measured according to this formula                                                                                               ![WhatsApp Image 2025-03-04 at 19.53.51_73afafc0.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # other popular distances measures:
#
# **Manhattan Distance :** Calculate the distannce between real vectors using the sum of their absolute difference. Also called City Block Distance.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Minkowski Distance :** Generalization of Euclidean and Manhattan Distance.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Hamming Distance :** Calculate the distance between binary vectors (Categorical Vectors)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ** Steps to be carried out during the K-NN algorithm are as follows :**
#
#
#
# 1.  Divide the data into training and test data.
# 2.   Choose the number of K neighbours, say K = 5
# 3. Take the K = 5 nearest neighbours of the new data point according to the Euclidian distance
#
#
#
#
#
# ![WhatsApp Image 2025-03-04 at 20.16.15_79adb64b.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Choosing an Optimal Value of K in KNN
#
# **Square Root Method** The most common method is to take the square root value of the total number of training instances of your data set. The rule of thumb is tot take an odd number. the method just works fine almost every time.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
import os
print(os.listdir('/content')) #Prints the content of the directory
# Out:
# ['.config', 'sample_data']

# %%
# Step 1: Load the dataset (Replace 'your_dataset.csv' with the actual file path)
df = pd.read_csv('/content/Iris.csv')

# Step 2: Convert Categorical Features to Numeric
label_encoders = {}
for col in df.select_dtypes(include=['object']).columns:  # Identify categorical columns
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])  # Convert categories to numbers
    label_encoders[col] = le  # Save encoder for reference
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-1055c73aa923> in <cell line: 0>()
#       1 # Step 1: Load the dataset (Replace 'your_dataset.csv' with the actual file path)
# ----> 2 df = pd.read_csv('/content/Iris.csv')
#       3
#       4 # Step 2: Convert Categorical Features to Numeric
#       5 label_encoders = {}
#
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
X_train = scaler.fit_transform(X_train)  # Fit on train data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4a209bc38945> in <cell line: 0>()
# ----> 1 X_train = scaler.fit_transform(X_train)  # Fit on train data
#
# NameError: name 'X_train' is not defined

# %%
X_train = scaler.fit_transform(X_train)  # Fit on train data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-4a209bc38945> in <cell line: 0>()
# ----> 1 X_train = scaler.fit_transform(X_train)  # Fit on train data
#
# NameError: name 'X_train' is not defined

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, Label
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-1b9c0705078e> in <cell line: 0>()
#       2 import numpy as np
#       3 from sklearn.model_selection import train_test_split
# ----> 4 from sklearn.preprocessing import StandardScaler, Label
#
# ImportError: cannot import name 'Label' from 'sklearn.preprocessing' (/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Assuming you have a dataset loaded in a pandas DataFrame called 'df'
# and the target variable column is called 'target'

# Split the data into training and testing sets
X = df.drop('target', axis=1)  # Features
y = df['target']  # Target variable
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42) # Adjust test_size and random_state as needed

# Now you can use X_test in your prediction
y_pred = knn.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-f1e2c768ce79> in <cell line: 0>()
#       3
#       4 # Split the data into training and testing sets
# ----> 5 X = df.drop('target', axis=1)  # Features
#       6 y = df['target']  # Target variable
#       7 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42) # Adjust test_size and random_state as needed
#
# NameError: name 'df' is not defined

# %%
# Step 8: Evaluate Model Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"KNN Model Accuracy: {accuracy * 100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-846ebaefd822> in <cell line: 0>()
#       1 # Step 8: Evaluate Model Accuracy
# ----> 2 accuracy = accuracy_score(y_test, y_pred)
#       3 print(f"KNN Model Accuracy: {accuracy * 100:.2f}%")
#
# NameError: name 'y_test' is not defined
